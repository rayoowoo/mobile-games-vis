# %%
import pandas as pd
from fastparquet import write

# %%
data = pd.read_csv('appstore_games.csv')

# %%
print ("null values: \n")
print(data.isna().sum())
# Out:
# null values:
#
# URL                                 0
# ID                                  0
# Name                                0
# Subtitle                        11746
# Icon URL                            0
# Average User Rating              9446
# User Rating Count                9446
# Price                              24
# In-app Purchases                 9324
# Description                         0
# Developer                           0
# Age Rating                          0
# Languages                          60
# Size                                1
# Primary Genre                       0
# Genres                              0
# Original Release Date               0
# Current Version Release Date        0
# dtype: int64

# %%
print("total null values: ", data.isna().sum().sum())
# Out:
# total null values:  40047

# %%
# Handling Missing Data

# %%
data[['Subtitle', 'Languages']] = data[['Subtitle', 'Languages']].fillna(value="No info")
data[['Average User Rating', 'User Rating Count', 'Price', 'In-app Purchases', 'Size']] = data[['Average User Rating', 'User Rating Count', 'Price', 'In-app Purchases', 'Size']].fillna(value=0.0)

# %%
# Handling duplicated data

# %%
duplicate_data = data[data.duplicated()]
print("number of duplicated rows: ", duplicate_data.shape)
# Out:
# number of duplicated rows:  (160, 18)

# %%
duplicate_data_URL = data[data.duplicated(['URL'])]
print(duplicate_data_URL.shape)
# Out:
# (160, 18)

# %%
print(len(data.URL.unique()))
# Out:
# 16847

# %%
print("shape of dataframe after dropping duplicates: ", data.drop_duplicates().shape)
# Out:
# shape of dataframe after dropping duplicates:  (16847, 18)

# %%
# Data binning

# %%
play_labels = ["No rating. Who knows?", 'horrible', 'somewhat playable', 'awesome']
category = [-1, 0.1, 2., 3.5, 5.]
data['Playability'] = pd.cut(data['Average User Rating'], labels=play_labels, bins=category, include_lowest=False)

# %%
print(data[['URL', 'Name', 'Average User Rating', 'Playability']])
# Out:
#                                                      URL  \
# 0       https://apps.apple.com/us/app/sudoku/id284921427
# 1      https://apps.apple.com/us/app/reversi/id284926400
# 2      https://apps.apple.com/us/app/morocco/id284946595
# 3      https://apps.apple.com/us/app/sudoku-free/id28...
# 4      https://apps.apple.com/us/app/senet-deluxe/id2...
# ...                                                  ...
# 17002  https://apps.apple.com/us/app/stack-puzzle-ris...
# 17003  https://apps.apple.com/us/app/eachother/id1474...
# 17004  https://apps.apple.com/us/app/rabbit-vs-tortoi...
# 17005  https://apps.apple.com/us/app/fatall/id1474963671
# 17006  https://apps.apple.com/us/app/the-three-kingdo...
#
#                             Name  Average User Rating            Playability
# 0                         Sudoku                  4.0                awesome
# 1                        Reversi                  3.5      somewhat playable
# 2                        Morocco                  3.0      somewhat playable
# 3                  Sudoku (Free)                  3.5      somewhat playable
# 4                   Senet Deluxe                  3.5      somewhat playable
# ...                          ...                  ...                    ...
# 17002  Stack Puzzle : Rise Tower                  0.0  No rating. Who knows?
# 17003                  EachOther                  0.0  No rating. Who knows?
# 17004         Rabbit Vs Tortoise                  0.0  No rating. Who knows?
# 17005                     FaTaLL                  0.0  No rating. Who knows?
# 17006   The Three Kingdoms :Bomb                  0.0  No rating. Who knows?
#
# [17007 rows x 4 columns]

# %%
# TODO: adjust the category to start from 0.1, that way 0.0 means no rating. and if no rating, clean up NaN's from
# plability to read "no rating, who knows"

# %%
data
# Out:
#                                                      URL          ID  \
# 0       https://apps.apple.com/us/app/sudoku/id284921427   284921427
# 1      https://apps.apple.com/us/app/reversi/id284926400   284926400
# 2      https://apps.apple.com/us/app/morocco/id284946595   284946595
# 3      https://apps.apple.com/us/app/sudoku-free/id28...   285755462
# 4      https://apps.apple.com/us/app/senet-deluxe/id2...   285831220
# ...                                                  ...         ...
# 17002  https://apps.apple.com/us/app/stack-puzzle-ris...  1474626442
# 17003  https://apps.apple.com/us/app/eachother/id1474...  1474919257
# 17004  https://apps.apple.com/us/app/rabbit-vs-tortoi...  1474962324
# 17005  https://apps.apple.com/us/app/fatall/id1474963671  1474963671
# 17006  https://apps.apple.com/us/app/the-three-kingdo...  1475076711
#
#                             Name                        Subtitle  \
# 0                         Sudoku                         No info
# 1                        Reversi                         No info
# 2                        Morocco                         No info
# 3                  Sudoku (Free)                         No info
# 4                   Senet Deluxe                         No info
# ...                          ...                             ...
# 17002  Stack Puzzle : Rise Tower  Blast the cubes, solve puzzle!
# 17003                  EachOther                         No info
# 17004         Rabbit Vs Tortoise                         No info
# 17005                     FaTaLL                Most fun game!!!
# 17006   The Three Kingdoms :Bomb                         No info
#
#                                                 Icon URL  Average User Rating  \
# 0      https://is2-ssl.mzstatic.com/image/thumb/Purpl...                  4.0
# 1      https://is4-ssl.mzstatic.com/image/thumb/Purpl...                  3.5
# 2      https://is5-ssl.mzstatic.com/image/thumb/Purpl...                  3.0
# 3      https://is3-ssl.mzstatic.com/image/thumb/Purpl...                  3.5
# 4      https://is1-ssl.mzstatic.com/image/thumb/Purpl...                  3.5
# ...                                                  ...                  ...
# 17002  https://is5-ssl.mzstatic.com/image/thumb/Purpl...                  0.0
# 17003  https://is2-ssl.mzstatic.com/image/thumb/Purpl...                  0.0
# 17004  https://is2-ssl.mzstatic.com/image/thumb/Purpl...                  0.0
# 17005  https://is1-ssl.mzstatic.com/image/thumb/Purpl...                  0.0
# 17006  https://is1-ssl.mzstatic.com/image/thumb/Purpl...                  0.0
#
#        User Rating Count  Price   In-app Purchases  \
# 0                 3553.0   2.99                  0
# 1                  284.0   1.99                  0
# 2                 8376.0   0.00                  0
# 3               190394.0   0.00                  0
# 4                   28.0   2.99                  0
# ...                  ...    ...                ...
# 17002                0.0   0.00                  0
# 17003                0.0   0.00                  0
# 17004                0.0   0.00                  0
# 17005                0.0   0.00  9.99, 49.99, 3.99
# 17006                0.0   0.00                  0
#
#                                              Description  \
# 0      Join over 21,000,000 of our fans and download ...
# 1      The classic game of Reversi, also known as Oth...
# 2      Play the classic strategy game Othello (also k...
# 3      Top 100 free app for over a year.\nRated "Best...
# 4      "Senet Deluxe - The Ancient Game of Life and A...
# ...                                                  ...
# 17002  The goal is very simple, move the square horiz...
# 17003  Collect a score while you play!!\n\nBy linking...
# 17004  "Rabbit Vs Tortoise is chess type cool simple ...
# 17005  Upgrade your character and use your skills to ...
# 17006  The protagonist uses the method of placing a b...
#
#                       Developer Age Rating  \
# 0      Mighty Mighty Good Games         4+
# 1              Kiss The Machine         4+
# 2                   Bayou Games         4+
# 3      Mighty Mighty Good Games         4+
# 4               RoGame Software         4+
# ...                         ...        ...
# 17002               Zhigang Pei         4+
# 17003             Sultan Shindi         4+
# 17004             Vishal Baldha         4+
# 17005              Tayrem Games         4+
# 17006              ming bo tang         4+
#
#                                                Languages         Size  \
# 0      DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...   15853568.0
# 1                                                     EN   12328960.0
# 2                                                     EN     674816.0
# 3      DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...   21552128.0
# 4      DA, NL, EN, FR, DE, EL, IT, JA, KO, NO, PT, RU...   34689024.0
# ...                                                  ...          ...
# 17002                                                 EN   64795648.0
# 17003                                                 EN  110341120.0
# 17004                                                 EN   23207936.0
# 17005                                                 EN  196750336.0
# 17006                                             EN, ZH   22952960.0
#
#       Primary Genre                                  Genres  \
# 0             Games                 Games, Strategy, Puzzle
# 1             Games                  Games, Strategy, Board
# 2             Games                  Games, Board, Strategy
# 3             Games                 Games, Strategy, Puzzle
# 4             Games       Games, Strategy, Board, Education
# ...             ...                                     ...
# 17002         Games  Games, Entertainment, Casual, Strategy
# 17003         Games                 Games, Family, Strategy
# 17004         Games                         Games, Strategy
# 17005         Games                 Games, Strategy, Action
# 17006         Games                 Games, Strategy, Puzzle
#
#       Original Release Date Current Version Release Date  \
# 0                11/07/2008                   30/05/2017
# 1                11/07/2008                   17/05/2018
# 2                11/07/2008                    5/09/2017
# 3                23/07/2008                   30/05/2017
# 4                18/07/2008                   22/07/2018
# ...                     ...                          ...
# 17002            30/07/2019                   30/07/2019
# 17003             1/08/2019                    1/08/2019
# 17004             3/08/2019                    3/08/2019
# 17005             1/08/2019                    1/08/2019
# 17006             2/08/2019                    2/08/2019
#
#                  Playability
# 0                    awesome
# 1          somewhat playable
# 2          somewhat playable
# 3          somewhat playable
# 4          somewhat playable
# ...                      ...
# 17002  No rating. Who knows?
# 17003  No rating. Who knows?
# 17004  No rating. Who knows?
# 17005  No rating. Who knows?
# 17006  No rating. Who knows?
#
# [17007 rows x 19 columns]

# %%
data['In-app Purchases'] = data['In-app Purchases'].astype(str)

# %%
write('games.parq', data)
